# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_file_path = '../data/MELBOURNE_HOUSE_PRICES_LESS.csv'

house_prices = pd.read_csv(data_file_path)

house_prices.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea
# 0          Yarra City Council
# 1          Yarra City Council
# ...

# %%
house_prices.describe()
# Out:
#               Rooms         Price      Postcode  Propertycount      Distance
# count  63023.000000  4.843300e+04  63023.000000   63023.000000  63023.000000
# mean       3.110595  9.978982e+05   3125.673897    7617.728131     12.684829
# std        0.957551  5.934989e+05    125.626877    4424.423167      7.592015
# min        1.000000  8.500000e+04   3000.000000      39.000000      0.000000
# 25%        3.000000  6.200000e+05   3056.000000    4380.000000      7.000000
# 50%        3.000000  8.300000e+05   3107.000000    6795.000000     11.400000
# 75%        4.000000  1.220000e+06   3163.000000   10412.000000     16.700000
# max       31.000000  1.120000e+07   3980.000000   21650.000000     64.100000

# %%
house_prices.Type.value_counts()
# Out:
# h    45053
# u    11655
# t     6315
# Name: Type, dtype: int64

# %%
house_prices.Method.value_counts()
# Out:
# S     34063
# PI     9790
# SP     8916
# VB     5956
# SN     2674
# PN      651
# W       484
# SA      416
# SS       73
# Name: Method, dtype: int64

# %%
house_prices = house_prices[house_prices.Method == 'S']

# %%
house_prices.CouncilArea.value_counts()
# Out:
# Boroondara City Council           2744
# Darebin City Council              2292
# Banyule City Council              2102
# Bayside City Council              1852
# Monash City Council               1846
# Brimbank City Council             1784
# Moreland City Council             1706
# Hume City Council                 1673
# Glen Eira City Council            1652
# Whittlesea City Council           1633
# Kingston City Council             1424
# Melbourne City Council            1408
# Moonee Valley City Council        1387
# Manningham City Council           1141
# Stonnington City Council          1072
# Yarra City Council                 986
# Maribyrnong City Council           951
# Whitehorse City Council            941
# Port Phillip City Council          867
# Wyndham City Council               840
# Maroondah City Council             708
# Hobsons Bay City Council           651
# Knox City Council                  576
# Frankston City Council             450
# ...

# %%
house_prices.Regionname.value_counts()
# Out:
# Northern Metropolitan         9695
# Southern Metropolitan         9477
# Western Metropolitan          6107
# Eastern Metropolitan          5296
# South-Eastern Metropolitan    2867
# Northern Victoria              283
# Eastern Victoria               215
# Western Victoria               123
# Name: Regionname, dtype: int64

# %%
house_prices.Postcode.value_counts()
# Out:
# 3073    717
# 3064    684
# 3046    536
# 3121    517
# 3165    494
# 3020    488
# 3150    474
# 3204    454
# 3058    445
# 3163    423
# 3040    419
# 3030    407
# 3146    402
# 3149    398
# 3072    391
# 3195    385
# 3130    382
# 3029    381
# 3082    371
# 3083    369
# 3101    362
# 3192    361
# 3122    361
# 3032    355
# 3088    350
# 3037    343
# 3056    338
# 3181    325
# 3145    322
# 3141    321
#        ...
# 3757      6
# 3427      6
# 3796      6
# 3008      5
# 3431      5
# 3782      5
# 3807      4
# 3115      4
# 3090      4
# 3809      4
# 3777      3
# 3428      3
# 3063      3
# 3765      3
# 3099      3
# 3158      2
# 3808      2
# 3795      2
# 3139      2
# 3160      2
# 3096      2
# 3786      1
# 3797      1
# 3114      1
# 3755      1
# 3781      1
# 3788      1
# 3759      1
# 3767      1
# 3770      1
# Name: Postcode, Length: 214, dtype: int64

# %%
house_prices.Suburb.value_counts()
# Out:
# Reservoir             717
# Bentleigh East        494
# Craigieburn           474
# Richmond              461
# Glen Iris             402
# Mount Waverley        398
# Preston               391
# Mill Park             371
# Kew                   362
# Cheltenham            361
# Hawthorn              361
# Glenroy               347
# Glen Waverley         347
# Brunswick             338
# Essendon              337
# Bundoora              328
# South Yarra           321
# Northcote             319
# Coburg                319
# Epping                314
# Malvern East          303
# Camberwell            303
# Brighton              301
# Hoppers Crossing      289
# Pascoe Vale           287
# Brighton East         284
# Doncaster East        276
# Greensborough         276
# Bentleigh             267
# Port Melbourne        267
#                      ...
# Lyndhurst               2
# Upwey                   2
# Healesville             2
# Skye                    2
# ...

# %%
house_prices.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0A5AA390>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(house_prices, figsize=(12, 8))
plt.show()

# %%
house_prices.plot(kind='scatter', x = 'Rooms', y = 'Price')

# %%
house_prices[house_prices.Type == 'h'].plot(kind='scatter', x = 'Rooms', y = 'Price')
